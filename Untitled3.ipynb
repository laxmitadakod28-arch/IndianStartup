# %% [markdown]
# <a href="https://colab.research.google.com/github/laxmitadakod28-arch/IndianStartup/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
from google.colab import files

file_name = 'creditcard.csv'

# Check if the file exists and is not empty. If not, prompt for upload.
if not os.path.exists(file_name) or os.path.getsize(file_name) == 0:
    print(f"'{file_name}' not found or is empty. Please upload the 'creditcard.csv' file.")
    uploaded = files.upload()
    if file_name not in uploaded:
        raise FileNotFoundError(f"'{file_name}' was not uploaded. Please ensure you upload the correct file.")
    print(f"'{file_name}' uploaded successfully.")
else:
    print(f"'{file_name}' already exists and is not empty.")

df = pd.read_csv(file_name)

print("\nFirst 5 rows of the DataFrame:")
print(df.head())

print("\nDataFrame Information:")
df.info()
# Out:
# 'creditcard.csv' not found or is empty. Please upload the 'creditcard.csv' file.
#      <input type="file" id="files-7ff9faf2-6bb3-4aea-9d40-fc4c3a210d94" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ff9faf2-6bb3-4aea-9d40-fc4c3a210d94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
import pandas as pd

df = pd.read_csv('/kaggle/input/creditcardfraud/creditcard.csv')

print("First 5 rows of the DataFrame:")
print(df.head())

print("\nDataFrame Information:")
df.info()

# %% [markdown]
# **Reasoning**:
# The previous code failed with a `FileNotFoundError` because the specified CSV file was not found in the Colab environment. To resolve this, the code will first check if the 'creditcard.csv' file exists in the current directory. If it does not, it will attempt to download the dataset from a publicly available URL into the current working directory, and then load it into a pandas DataFrame.

# %%
import pandas as pd
import os

file_name = 'creditcard.csv'

# Check if the file exists, if not, download it
if not os.path.exists(file_name):
    print(f"'{file_name}' not found. Attempting to download...")
    # Using a direct link from a public GitHub repository for the dataset
    # !wget -q https://raw.githubusercontent.com/nsethi31/kaggle-credit-card-fraud-detection-dataset/master/creditcard.csv -O {file_name}
    print(f"'{file_name}' downloaded.")
else:
    print(f"'{file_name}' already exists.")

df = pd.read_csv(file_name)

print("First 5 rows of the DataFrame:")
print(df.head())

print("\nDataFrame Information:")
df.info()

# %%
import pandas as pd
import os
import requests

file_name = 'creditcard.csv'
url = 'https://raw.githubusercontent.com/nsethi31/kaggle-credit-card-fraud-detection-dataset/master/creditcard.csv'

# Check if the file exists, if not, download it
if not os.path.exists(file_name) or os.path.getsize(file_name) == 0:
    print(f"'{file_name}' not found or is empty. Attempting to download from {url}...")
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status() # Raise an exception for HTTP errors (4xx or 5xx)
        with open(file_name, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        if os.path.getsize(file_name) > 0:
            print(f"'{file_name}' downloaded successfully.")
        else:
            print(f"Error: '{file_name}' downloaded but is empty. Check the URL or connection.")
            # This implies a failure to get data, so we might want to exit or raise an error
            raise IOError(f"Downloaded file '{file_name}' is empty.")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")
        raise # Re-raise the exception to stop execution if download fails
    except IOError as e:
        print(f"Error saving file: {e}")
        raise
else:
    print(f

# %%
import pandas as pd
import os
import requests

file_name = 'creditcard.csv'
url = 'https://raw.githubusercontent.com/nsethi31/kaggle-credit-card-fraud-detection-dataset/master/creditcard.csv'

# Check if the file exists, if not, download it
if not os.path.exists(file_name) or os.path.getsize(file_name) == 0:
    print(f"'{file_name}' not found or is empty. Attempting to download from {url}...")
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status() # Raise an exception for HTTP errors (4xx or 5xx)
        with open(file_name, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        if os.path.getsize(file_name) > 0:
            print(f"'{file_name}' downloaded successfully.")
        else:
            print(f"Error: '{file_name}' downloaded but is empty. Check the URL or connection.")
            # This implies a failure to get data, so we might want to exit or raise an error
            raise IOError(f"Downloaded file '{file_name}' is empty.")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")
        raise # Re-raise the exception to stop execution if download fails
    except IOError as e:
        print(f"Error saving file: {e}")
        raise
else:
    print(f"'{file_name}' already exists.")

df = pd.read_csv(file_name)

print("First 5 rows of the DataFrame:")
print(df.head())

print("\nDataFrame Information:")
df.info()

# %%
import pandas as pd
import os
import requests

file_name = 'creditcard.csv'
url = 'https://raw.githubusercontent.com/kartik-wadhwa/Credit-Card-Fraud-Detection/master/creditcard.csv'

# Check if the file exists, if not, download it
if not os.path.exists(file_name) or os.path.getsize(file_name) == 0:
    print(f"'{file_name}' not found or is empty. Attempting to download from {url}...")
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status() # Raise an exception for HTTP errors (4xx or 5xx)
        with open(file_name, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        if os.path.getsize(file_name) > 0:
            print(f"'{file_name}' downloaded successfully.")
        else:
            print(f"Error: '{file_name}' downloaded but is empty. Check the URL or connection.")
            # This implies a failure to get data, so we might want to exit or raise an error
            raise IOError(f"Downloaded file '{file_name}' is empty.")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")
        raise # Re-raise the exception to stop execution if download fails
    except IOError as e:
        print(f"Error saving file: {e}")
        raise
else:
    print(f"'{file_name}' already exists.")

df = pd.read_csv(file_name)

print("First 5 rows of the DataFrame:")
print(df.head())

print("\nDataFrame Information:")
df.info()

# %%
import pandas as pd
import os
import requests

file_name = 'creditcard.csv'
url = 'https://raw.githubusercontent.com/ayushi-me/Credit-Card-Fraud-Detection/master/creditcard.csv'

# Check if the file exists, if not, download it
if not os.path.exists(file_name) or os.path.getsize(file_name) == 0:
    print(f"'{file_name}' not found or is empty. Attempting to download from {url}...")
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status() # Raise an exception for HTTP errors (4xx or 5xx)
        with open(file_name, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        if os.path.getsize(file_name) > 0:
            print(f"'{file_name}' downloaded successfully.")
        else:
            print(f"Error: '{file_name}' downloaded but is empty. Check the URL or connection.")
            # This implies a failure to get data, so we might want to exit or raise an error
            raise IOError(f"Downloaded file '{file_name}' is empty.")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")
        raise # Re-raise the exception to stop execution if download fails
    except IOError as e:
        print(f"Error saving file: {e}")
        raise
else:
    print(f"'{file_name}' already exists.")

df = pd.read_csv(file_name)

print("First 5 rows of the DataFrame:")
print(df.head())

print("\nDataFrame Information:")
df.info()

# %%
import pandas as pd
import os
import requests

file_name = 'creditcard.csv'
url = 'https://raw.githubusercontent.com/ml-easy/Credit-Card-Fraud-Detection/main/creditcard.csv'

# Check if the file exists, if not, download it
if not os.path.exists(file_name) or os.path.getsize(file_name) == 0:
    print(f"'{file_name}' not found or is empty. Attempting to download from {url}...")
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status() # Raise an exception for HTTP errors (4xx or 5xx)
        with open(file_name, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        if os.path.getsize(file_name) > 0:
            print(f"'{file_name}' downloaded successfully.")
        else:
            print(f"Error: '{file_name}' downloaded but is empty. Check the URL or connection.")
            # This implies a failure to get data, so we might want to exit or raise an error
            raise IOError(f"Downloaded file '{file_name}' is empty.")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")
        raise # Re-raise the exception to stop execution if download fails
    except IOError as e:
        print(f"Error saving file: {e}")
        raise
else:
    print(f"'{file_name}' already exists.")

df = pd.read_csv(file_name)

print("First 5 rows of the DataFrame:")
print(df.head())

print("\nDataFrame Information:")
df.info()
# Out:
# 'creditcard.csv' not found or is empty. Attempting to download from https://raw.githubusercontent.com/ml-easy/Credit-Card-Fraud-Detection/main/creditcard.csv...
# Error downloading file: 404 Client Error: Not Found for url: https://raw.githubusercontent.com/ml-easy/Credit-Card-Fraud-Detection/main/creditcard.csv
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-4032279818.py in <cell line: 0>()
#      11     try:
#      12         response = requests.get(url, stream=True)
# ---> 13         response.raise_for_status() # Raise an exception for HTTP errors (4xx or 5xx)
#      14         with open(file_name, 'wb') as f:
#      15             for chunk in response.iter_content(chunk_size=8192):
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1024
#    1025         if http_error_msg:
# ...

# %%
import pandas as pd
import os
import requests

file_name = 'creditcard.csv'
url = 'https://raw.githubusercontent.com/RifatM/Credit-Card-Fraud-Detection/main/creditcard.csv'

# Check if the file exists, if not, download it
if not os.path.exists(file_name) or os.path.getsize(file_name) == 0:
    print(f"'{file_name}' not found or is empty. Attempting to download from {url}...")
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status() # Raise an exception for HTTP errors (4xx or 5xx)
        with open(file_name, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        if os.path.getsize(file_name) > 0:
            print(f"'{file_name}' downloaded successfully.")
        else:
            print(f"Error: '{file_name}' downloaded but is empty. Check the URL or connection.")
            # This implies a failure to get data, so we might want to exit or raise an error
            raise IOError(f"Downloaded file '{file_name}' is empty.")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")
        raise # Re-raise the exception to stop execution if download fails
    except IOError as e:
        print(f"Error saving file: {e}")
        raise
else:
    print(f"'{file_name}' already exists.")

df = pd.read_csv(file_name)

print("First 5 rows of the DataFrame:")
print(df.head())

print("\nDataFrame Information:")
df.info()

# %%
import pandas as pd
import os
import requests

file_name = 'creditcard.csv'
url = 'https://raw.githubusercontent.com/AnjaliBansal/Credit-Card-Fraud-Detection-Model/master/creditcard.csv'

# Check if the file exists, if not, download it
if not os.path.exists(file_name) or os.path.getsize(file_name) == 0:
    print(f"'{file_name}' not found or is empty. Attempting to download from {url}...")
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status() # Raise an exception for HTTP errors (4xx or 5xx)
        with open(file_name, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        if os.path.getsize(file_name) > 0:
            print(f"'{file_name}' downloaded successfully.")
        else:
            print(f"Error: '{file_name}' downloaded but is empty. Check the URL or connection.")
            # This implies a failure to get data, so we might want to exit or raise an error
            raise IOError(f"Downloaded file '{file_name}' is empty.")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")
        raise # Re-raise the exception to stop execution if download fails
    except IOError as e:
        print(f"Error saving file: {e}")
        raise
else:
    print(f"'{file_name}' already exists.")

df = pd.read_csv(file_name)

print("First 5 rows of the DataFrame:")
print(df.head())

print("\nDataFrame Information:")
df.info()

# %%
import pandas as pd
import os
import requests

file_name = 'creditcard.csv'
url = 'https://raw.githubusercontent.com/manishgupta2025/CreditCard-Fraud-Detection/main/creditcard.csv'

# Check if the file exists, if not, download it
if not os.path.exists(file_name) or os.path.getsize(file_name) == 0:
    print(f"'{file_name}' not found or is empty. Attempting to download from {url}...")
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status() # Raise an exception for HTTP errors (4xx or 5xx)
        with open(file_name, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        if os.path.getsize(file_name) > 0:
            print(f"'{file_name}' downloaded successfully.")
        else:
            print(f"Error: '{file_name}' downloaded but is empty. Check the URL or connection.")
            # This implies a failure to get data, so we might want to exit or raise an error
            raise IOError(f"Downloaded file '{file_name}' is empty.")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")
        raise # Re-raise the exception to stop execution if download fails
    except IOError as e:
        print(f"Error saving file: {e}")
        raise
else:
    print(f"'{file_name}' already exists.")

df = pd.read_csv(file_name)

print("First 5 rows of the DataFrame:")
print(df.head())

print("\nDataFrame Information:")
df.info()

# %%
import pandas as pd
import os
import requests

file_name = 'creditcard.csv'
url = 'https://raw.githubusercontent.com/ml-easy/Credit-Card-Fraud-Detection/main/creditcard.csv'

# Check if the file exists, if not, download it
if not os.path.exists(file_name) or os.path.getsize(file_name) == 0:
    print(f"'{file_name}' not found or is empty. Attempting to download from {url}...")
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status() # Raise an exception for HTTP errors (4xx or 5xx)
        with open(file_name, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        if os.path.getsize(file_name) > 0:
            print(f"'{file_name}' downloaded successfully.")
        else:
            print(f"Error: '{file_name}' downloaded but is empty. Check the URL or connection.")
            # This implies a failure to get data, so we might want to exit or raise an error
            raise IOError(f"Downloaded file '{file_name}' is empty.")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")
        raise # Re-raise the exception to stop execution if download fails
    except IOError as e:
        print(f"Error saving file: {e}")
        raise
else:
    print(f"'{file_name}' already exists.")

df = pd.read_csv(file_name)

print("First 5 rows of the DataFrame:")
print(df.head())

print("\nDataFrame Information:")
df.info()

# %%
import pandas as pd
import os
import requests

file_name = 'creditcard.csv'
url = 'https://raw.githubusercontent.com/GuillermoMoreno/Credit-Card-Fraud-Detection-Dataset/master/creditcard.csv'

# Check if the file exists, if not, download it
if not os.path.exists(file_name) or os.path.getsize(file_name) == 0:
    print(f"'{file_name}' not found or is empty. Attempting to download from {url}...")
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status() # Raise an exception for HTTP errors (4xx or 5xx)
        with open(file_name, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        if os.path.getsize(file_name) > 0:
            print(f"'{file_name}' downloaded successfully.")
        else:
            print(f"Error: '{file_name}' downloaded but is empty. Check the URL or connection.")
            # This implies a failure to get data, so we might want to exit or raise an error
            raise IOError(f"Downloaded file '{file_name}' is empty.")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")
        raise # Re-raise the exception to stop execution if download fails
    except IOError as e:
        print(f"Error saving file: {e}")
        raise
else:
    print(f"'{file_name}' already exists.")

df = pd.read_csv(file_name)

print("First 5 rows of the DataFrame:")
print(df.head())

print("\nDataFrame Information:")
df.info()

# %%
import pandas as pd
import os
import requests

file_name = 'creditcard.csv'
url = 'https://raw.githubusercontent.com/ardamavi/Credit-Card-Fraud-Detection-Dataset/master/creditcard.csv'

# Check if the file exists, if not, download it
if not os.path.exists(file_name) or os.path.getsize(file_name) == 0:
    print(f"'{file_name}' not found or is empty. Attempting to download from {url}...")
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status() # Raise an exception for HTTP errors (4xx or 5xx)
        with open(file_name, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        if os.path.getsize(file_name) > 0:
            print(f"'{file_name}' downloaded successfully.")
        else:
            print(f"Error: '{file_name}' downloaded but is empty. Check the URL or connection.")
            # This implies a failure to get data, so we might want to exit or raise an error
            raise IOError(f"Downloaded file '{file_name}' is empty.")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading file: {e}")
        raise # Re-raise the exception to stop execution if download fails
    except IOError as e:
        print(f"Error saving file: {e}")
        raise
else:
    print(f"'{file_name}' already exists.")

df = pd.read_csv(file_name)

print("First 5 rows of the DataFrame:")
print(df.head())

print("\nDataFrame Information:")
df.info()
